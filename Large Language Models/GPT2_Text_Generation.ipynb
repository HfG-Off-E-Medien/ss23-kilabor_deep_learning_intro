# %%
# %%capture
# !pip install transformers

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')
model = GPT2LMHeadModel.from_pretrained('gpt2-large', pad_token_id=tokenizer.eos_token_id)
# Out:
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
sentence = "I like Ice Cream"
input_ids = tokenizer.encode(sentence, return_tensors='pt')

# %%
output = model.generate(input_ids, max_length = 100, num_beams=12, no_repeat_ngram_size=2, early_stopping=True)

# %%
tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# "I like Ice Cream Sandwich, but I don't like it as much as I used to. I'm not sure if it's because I've been using it for so long, or if I just haven't gotten the hang of it yet. Either way, I can't wait to get my hands on Android 4.1.2.\n\nI'll be sure to update this post with any new information as it becomes available."
