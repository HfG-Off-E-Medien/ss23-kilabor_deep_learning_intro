# %%
# %%capture
# !pip install transformers

# %% [markdown]
# Binary Classification

# %%
# Import Libraries
import torch
from transformers import AutoTokenizer, BertForSequenceClassification

# %%
# Load Model
tokenizer = AutoTokenizer.from_pretrained("textattack/bert-base-uncased-yelp-polarity")
model = BertForSequenceClassification.from_pretrained("textattack/bert-base-uncased-yelp-polarity")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/520 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
# Look at what the tokenizer is doing.
prompt = "Hello, my dog is cute"
tokenized_prompt = tokenizer(prompt, return_tensors="pt")
print(tokenized_prompt)
# Out:
# {'input_ids': tensor([[  101,  7592,  1010,  2026,  3899,  2003, 10140,   102]]), 'token_type_ids': tensor([[0, 0, 0, 0, 0, 0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1, 1]])}

# %%
# Make sentiment prediction
with torch.no_grad():
    logits = model(**tokenized_prompt).logits

# %%
def logits_to_sentiment(logits):
    predicted_class_id = logits.argmax().item()
    if predicted_class_id == 0:
       return 'Negative'
    else:
       return 'Positive'

# %%
pred_sentiment = probs_to_sentiment(probs)
print(pred_sentiment)
# Out:
# Probabilities:  tensor([[0.0083, 0.9917]])
# Positive
